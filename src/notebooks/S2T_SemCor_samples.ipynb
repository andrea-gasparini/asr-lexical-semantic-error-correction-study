# %% [markdown]
# ## Dependencies

# %%
import os
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
ROOT_DIR = "/content/drive/My Drive/data/nlp/"
SEMCOR_SPEECH_PATH = f"{ROOT_DIR}speech2text/SemCor/"

if not os.path.isdir(f"{ROOT_DIR}WSD_Training_Corpora"):
    ! wget http://nlp.uniroma1.it/wsdeval/data/WSD_Training_Corpora.zip
    ! unzip WSD_Training_Corpora
    SEMCOR_PATH = "WSD_Training_Corpora/SemCor/semcor"
else:
    SEMCOR_PATH = f"{ROOT_DIR}WSD_Training_Corpora/SemCor/semcor"
# Out:
# Mounted at /content/drive

# %%
! pip install --upgrade --quiet transformers torchmetrics
# Out:
#      |████████████████████████████████| 4.0 MB 4.2 MB/s
#      |████████████████████████████████| 398 kB 80.0 MB/s
#      |████████████████████████████████| 77 kB 7.1 MB/s
#      |████████████████████████████████| 895 kB 49.9 MB/s
#      |████████████████████████████████| 596 kB 77.1 MB/s
#      |████████████████████████████████| 6.5 MB 36.8 MB/s

# %%
import re
import nltk
import torch
import librosa
import torch
import numpy as np
import pandas as pd
import IPython.display as display
import torchmetrics

from typing import *
from pprint import pprint
from pathlib import Path
from dataclasses import dataclass, field
from nltk.corpus import wordnet as wn
from xml.etree import cElementTree as etree
from tqdm import tqdm
from torchmetrics.functional.text.wer import word_error_rate
from torchmetrics.functional.text.cer import char_error_rate
from transformers import AutoTokenizer, AutoModel, Wav2Vec2ForCTC, HubertForCTC, Wav2Vec2Tokenizer, Wav2Vec2Processor

# %% [markdown]
# ## Utils

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
tokenizer = AutoTokenizer.from_pretrained('roberta-base')
encoder = AutoModel.from_pretrained('roberta-base')
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
wnpos_map = dict(NOUN='n', VERB='v', ADJ='a', ADV='r')

@dataclass
class Token:
    ''' a token in a given context'''
  
    text: str                    # input token (word form)
    sent: List['Token']          # the whole sentence the token is contained in
    token_index: int             # token index within sent
    subword_index_start: int
    lemma: Optional[str] = None
    pos: Optional[str] = None
    id_: Optional[str] = None
    sensekeys: List[str] = field(default_factory=list) 

    def wnpos(self):
        if self.pos is None:
            return None
        return wnpos_map.get(self.pos)
        
    def possible_senses(self):
        assert self.lemma
        return wn.lemmas(self.lemma, self.wnpos())

    def possible_keys(self):
        return [sense.key() for sense in self.possible_senses()]

    def possible_lexnames(self):
        return list(dict.fromkeys([sense.synset().lexname() for sense in self.possible_senses()]))

    def gold_senses(self):
        return [wn.lemma_from_key(sk) for sk in self.sensekeys]

    def gold_keys(self):
        return self.sensekeys

    def gold_lexnames(self):
        return [sense.synset().lexname() for sense in self.gold_senses()]

    @property
    def is_tagged(self):
        return bool(self.sensekeys)

    @property
    def subwords(self):
        '''creates the subwords of the token'''
        if not hasattr(self, '_subwords'):
            # RoBERTa tokenizer requires leading space
            self._subwords = tokenizer.tokenize(' ' + self.text.lstrip())
        return self._subwords

    @property
    def subword_index_end(self):
        return self.subword_index_start + len(self.subwords)

# %%
def read_corpus(xml_path, key_path, max=50) -> List[List[Token]]:
    
    sentences = []

    keys = Path(key_path).read_text().strip().splitlines()
    keys = [l.split(' ') for l in keys]
    keys = {l[0]: l[1:] for l in keys}

    for i, sent_xml in enumerate(list(etree.parse(xml_path).iter('sentence'))[:max]):
        sent = []
        subword_index_start = 0
        for token_index, token_xml in enumerate(sent_xml):
            if token_xml.tag == 'instance':
                # <instance>
                gold = keys.get(token_xml.attrib['id'], [])
            else:
                # <wf>
                gold = []
            token = Token(
                token_xml.text,
                sent,
                token_index,
                subword_index_start,
                token_xml.attrib['lemma'],
                token_xml.attrib['pos'],
                token_xml.attrib.get('id'),
                gold 
            )
            subword_index_start = token.subword_index_end
            sent.append(token)
        if any([t.is_tagged for t in sent]):
            sentences.append(sent)

    return sentences

# %% [markdown]
# ## Speech2text models

# %%
BASE_MODEL_PATH = f"{ROOT_DIR}speech2text/models/wav2vec2-base-960h"             # "facebook/wav2vec2-base-960h"
LARGE_MODEL_PATH = f"{ROOT_DIR}speech2text/models/wav2vec2-large-960h"           # "facebook/wav2vec2-large-960h"
XLSR_MODEL_PATH = f"{ROOT_DIR}speech2text/models/wav2vec2-large-xlsr-53-english" # "jonatasgrosman/wav2vec2-large-xlsr-53-english"
HUBERT_MODEL_PATH = f"{ROOT_DIR}speech2text/models/hubert-large-ls960-ft"        # "facebook/hubert-large-ls960-ft"
HUBERT_XLARGE_MODEL_PATH = f"facebook/hubert-xlarge-ls960-ft"        # "facebook/hubert-xlarge-ls960-ft"

base_tokenizer = Wav2Vec2Processor.from_pretrained(BASE_MODEL_PATH)
base_model = Wav2Vec2ForCTC.from_pretrained(BASE_MODEL_PATH)

large_tokenizer = Wav2Vec2Processor.from_pretrained(LARGE_MODEL_PATH)
large_model = Wav2Vec2ForCTC.from_pretrained(LARGE_MODEL_PATH)

xlsr_tokenizer = Wav2Vec2Processor.from_pretrained(XLSR_MODEL_PATH)
xlsr_model = Wav2Vec2ForCTC.from_pretrained(XLSR_MODEL_PATH)

hubert_tokenizer = Wav2Vec2Processor.from_pretrained(HUBERT_MODEL_PATH)
hubert_model = HubertForCTC.from_pretrained(HUBERT_MODEL_PATH)

hubert_xlarge_tokenizer = Wav2Vec2Processor.from_pretrained(HUBERT_XLARGE_MODEL_PATH)
hubert_xlarge_model = HubertForCTC.from_pretrained(HUBERT_XLARGE_MODEL_PATH)
# Out:
# Downloading:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/292 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.59G [00:00<?, ?B/s]

# %%
def load_audio(file_path: str, sampling_rate: int = 16_000) -> np.ndarray:
    speech, rate = librosa.load(file_path, sr=sampling_rate)
    return speech

# %%
def speech2text(speech: np.ndarray,
                model: Wav2Vec2ForCTC,
                processor: Wav2Vec2Processor,
                sampling_rate: int = 16_000) -> str:
    input_values = processor(speech, sampling_rate=sampling_rate, return_tensors="pt").input_values
    logits = model(input_values).logits
    predicted_ids = torch.argmax(logits, dim=-1)
    transcriptions = processor.decode(predicted_ids[0])
    return transcriptions.lower()

def speech2textCMP(speech: np.ndarray) -> str:
    out = dict()
    out["BASE_MODEL"] = speech2text(speech, base_model, base_tokenizer)
    out["LARGE_MODEL"] = speech2text(speech, large_model, large_tokenizer)
    out["XLSR_MODEL"] = speech2text(speech, xlsr_model, xlsr_tokenizer)
    out["HUBERT_MODEL"] = speech2text(speech, hubert_model, hubert_tokenizer)
    return out

# %% [markdown]
# ## SemCor samples

# %%
# @title Util functions

def load_semcor_audio_sample(sample_idx: int, path: str,
                             postfix: str = "") -> np.ndarray:
    if path is None: 
        path = f"{SEMCOR_SPEECH_PATH}andrea/"
    semcor_sample_path = f"{path}SemCor#{sample_idx+1}{postfix}.wav"
    assert os.path.isfile(semcor_sample_path), f"Speech SemCor sample {semcor_sample_path} does not exist"
    return load_audio(semcor_sample_path)

def get_semcor_sample_transcriptions(sample_idx: int,
                                     path: Optional[str] = None,
                                     postfix: str = "") -> Dict:
    sample = " ".join([tok.text for tok in SemCor[sample_idx]]).lower()
    sample = re.sub(r'[^\w\s]', '', sample)

    out = speech2textCMP(load_semcor_audio_sample(sample_idx, path, postfix=postfix))

    for model, prediction in out.items():
        wer = word_error_rate(prediction, sample)
        out[model] = [prediction, wer.item()]

    out["SemCor"] = [sample, ""]

    return out

def show_semcor_transcriptions_comparison(out: Dict) -> pd.DataFrame:

    pd.set_option('display.max_colwidth', None)

    df = pd.DataFrame.from_dict(out, orient='index')
    df.columns = ["Transcription", "WER"]
    
    return df.style.set_properties(**{'text-align': 'left'})

# %%
SemCor = read_corpus(SEMCOR_PATH + ".data.xml",
                     SEMCOR_PATH + ".gold.key.txt",
                     max=40)

# %%
import json

outs = list()

TRANSCRIPTIONS_JSON = f"{SEMCOR_SPEECH_PATH}transcriptions.json"

if os.path.isfile(TRANSCRIPTIONS_JSON):
    with open(TRANSCRIPTIONS_JSON) as f:
        outs = json.load(f)
else:    
    outs = [get_semcor_sample_transcriptions(i) for i in range(len(SemCor))]
    with open(TRANSCRIPTIONS_JSON, "w") as f:
        f.write(json.dumps(outs))

# %%
douts = {
    "HUBERT_MODEL": [],
    "XLSR_MODEL": [],
    "LARGE_MODEL": [],
    "BASE_MODEL": [],
    "SemCor": []
}
for dic in outs:
    for key, value in dic.items():
        douts[key] += [value]

# %%
# average Word Error Rate
sum([x[1] / len(douts["HUBERT_MODEL"]) for x in douts["HUBERT_MODEL"]])
# Out:
# 0.11923798834905032

# %%
# best model per sample
a = [(("HUBERT_MODEL", x["HUBERT_MODEL"][1]), ("XLSR_MODEL", x["XLSR_MODEL"][1]), ("LARGE_MODEL", x["LARGE_MODEL"][1]), ("BASE_MODEL", x["BASE_MODEL"][1])) for x in outs]
[min(x, key=lambda y : y[1]) for x in a]
# Out:
# [('HUBERT_MODEL', 0.0625),
#  ('XLSR_MODEL', 0.1666666716337204),
#  ('XLSR_MODEL', 0.0),
#  ('LARGE_MODEL', 0.1666666716337204),
#  ('XLSR_MODEL', 0.1111111119389534),
#  ('HUBERT_MODEL', 0.0),
#  ('LARGE_MODEL', 0.0),
#  ('XLSR_MODEL', 0.10000000149011612),
#  ('HUBERT_MODEL', 0.0),
#  ('HUBERT_MODEL', 0.0625),
#  ('XLSR_MODEL', 0.0),
#  ('LARGE_MODEL', 0.07407407462596893),
#  ('HUBERT_MODEL', 0.1666666716337204),
#  ('XLSR_MODEL', 0.1034482792019844),
#  ('HUBERT_MODEL', 0.07692307978868484),
#  ('HUBERT_MODEL', 0.0),
#  ('HUBERT_MODEL', 0.125),
#  ('HUBERT_MODEL', 0.0),
#  ('HUBERT_MODEL', 0.0),
#  ('HUBERT_MODEL', 0.05882352963089943),
#  ('HUBERT_MODEL', 0.0),
#  ('XLSR_MODEL', 0.07692307978868484),
#  ('HUBERT_MODEL', 0.0833333358168602),
#  ('HUBERT_MODEL', 0.1111111119389534),
#  ('HUBERT_MODEL', 0.43478259444236755),
#  ('HUBERT_MODEL', 0.0),
#  ('HUBERT_MODEL', 0.06666667014360428),
#  ('HUBERT_MODEL', 0.0714285746216774),
#  ('XLSR_MODEL', 0.0625),
#  ('HUBERT_MODEL', 0.2857142984867096),
#  ('HUBERT_MODEL', 0.0833333358168602),
#  ('HUBERT_MODEL', 0.0714285746216774),
#  ('HUBERT_MODEL', 0.07692307978868484),
#  ('HUBERT_MODEL', 0.0),
#  ('XLSR_MODEL', 0.05882352963089943),
#  ('HUBERT_MODEL', 0.20000000298023224),
#  ('HUBERT_MODEL', 0.0),
#  ('HUBERT_MODEL', 0.1666666716337204),
#  ('LARGE_MODEL', 0.23076923191547394),
#  ('XLSR_MODEL', 0.1538461595773697)]

# %%
wrongs_list = list()
for sample_i, out in enumerate(outs):
    sample = out["SemCor"][0]
    trans = out["HUBERT_MODEL"][0]

    cnt = 0
    sw_trans = ""
    split_trans = trans.split()
    split_sample = sample.split()

    wrongs = dict()
    for word_i, sw in enumerate(split_sample):
        if word_i == len(split_trans):
            wrongs[word_i] = (sw, "")
            break

        sw_trans = split_trans[word_i]
        if sw != sw_trans:
            wrongs[word_i] = (sw, sw_trans)

    wrongs2 = dict()
    for word_i, sw in reversed(list(enumerate(split_sample))):
        if word_i == 0:
            wrongs2[word_i] = (sw, "")
            break

        trans_i = word_i - (len(split_sample) - len(split_trans))
        sw_trans = split_trans[trans_i]
        if sw != sw_trans:
            wrongs2[word_i] = (sw, sw_trans)

    for k, v in wrongs.copy().items():
        if k not in wrongs2:
            del wrongs[k]
        else:
            wrongs[k] = (v[0], [v[1], wrongs2[k][1]])

    if wrongs: pprint(wrongs)

    wrongs_list.append(wrongs)

    print("")
# Out:
# {15: ('program', ['programme', 'programme'])}
#
# {8: ('program', ['programm', 'giveaway']),
#  12: ('that', ['there', 'one']),
#  13: ('has', ['as', 'there']),
#  18: ('employee', ['emploimoral', 'improved']),
#  19: ('morale', ['and', 'emploimoral'])}
#
# {10: ('program', ['programme', 'programme'])}
#
# {6: ('reduced', ['reduce', 'absentism']),
#  7: ('absenteeism', ['absentism', 'turn']),
#  8: ('turnover', ['turn', 'over']),
#  14: ('improved', ['to', 'improve'])}
#
# {2: ('set', ['sad', 'sad']), 7: ('employee', ['emploe', 'emploe'])}
#
#
# {3: ('or', ['offence', 'offence']), 4: ('fancier', ['ere', 'ere'])}
#
# {9: ('etc', ['et', 'cetera'])}
#
#
# {4: ('employee', ['employe', 'employe'])}
#
# {11: ('employees', ['employes', 'employes'])}
#
# {9: ('lighting', ['lightning', 'rest']),
#  14: ('airconditioning', ['air', 'conditioning'])}
#
# {19: ('per', ['pay', 'cents']),
#  20: ('hour', ['our', 'pay']),
#  21: ('cost', ['costing', 'our']),
#  22: ('in', ['wages', 'costing'])}
#
# {6: ('employee', ['implete', 'benefits']),
#  13: ('profitsharing', ['profit', 'sharing']),
#  27: ('motors', ['american', 'modors'])}
#
# {2: ('employees', ['employies', 'employies'])}
#
#
# {10: ('company', ["company's", 'the']), 11: ('s', ['share', "company's"])}
#
#
#
# {8: ('employee', ['imply', 'imply'])}
#
#
# {4: ('limit', ['lein', 'its'])}
#
# {22: ('work', ['workweek', 'uninterrupted']), 23: ('week', ['', 'workweek'])}
#
# {3: ('policing', ['polising', 'polising']), 4: ('washup', ['washp', 'washp'])}
#
# {3: ('work', ['worse', 'caduales']),
#  4: ('schedules', ['caduales', 'for']),
#  6: ('boiler', ['boleberators', 'guard']),
#  7: ('operators', ['guard', 'and']),
#  8: ('guards', ['and', 'other']),
#  9: ('and', ['other', 'twenty']),
#  10: ('other', ['twenty', 'four']),
#  11: ('24', ['four', 'hour']),
#  14: ('7', ['seven', 'day']),
#  22: ('overtime', ['over', 'time'])}
#
#
# {13: ('cafeteria', ['cafetri', 'cafetri'])}
#
# {7: ('cafeteria', ['cafateria', 'cafateria']),
#  11: ('shift', ['sheift', 'sheift'])}
#
# {8: ('cafeteria', ['cafet', 'ri'])}
#
# {5: ('cafeteria', ['cafetrial', 'cafetrial']),
#  6: ('help', ['pork', 'pork']),
#  7: ('work', ['part', 'part']),
#  8: ('parttime', ['time', 'time'])}
#
# {1: ('staggered', ['staggared', 'staggared'])}
#
# {7: ('menu', ['manue', 'manue'])}
#
# {3: ('gradual', ['gradwell', 'gradwell'])}
#
#
# {6: ('commensurate', ['commercuary', 'commercuary']),
#  16: ('program', ['programme', 'programme'])}
#
# {2: ('audited', ['algited', 'algited']),
#  7: ('weed', ['wed', 'wed']),
#  13: ('least', ['lees', 'lees'])}
#
#
# {8: ('employee', ['employ', 'your']),
#  14: ('plant', ["plan's", 'your']),
#  15: ('s', ['financial', "plan's"])}
#
# {1: ('an', ['and', 'and']),
#  2: ('employee', ['employees', 'employees']),
#  3: ('s', ['gard', 'gard']),
#  4: ('garden', ['and', 'and'])}
#
# {0: ('would', ['vouda', '']),
#  1: ('a', ['camera', 'vouda']),
#  9: ('pertinent', ['to', 'pertinant']),
#  11: ('plant', ['safety', 'plan'])}

# %%
pprint(wrongs_list[0])
show_semcor_transcriptions_comparison(outs[0])
# Out:
# {15: ('program', ['programme', 'programme'])}
# <style type="text/css">
# #T_2e53c_row0_col0, #T_2e53c_row0_col1, #T_2e53c_row1_col0, #T_2e53c_row1_col1, #T_2e53c_row2_col0, #T_2e53c_row2_col1, #T_2e53c_row3_col0, #T_2e53c_row3_col1, #T_2e53c_row4_col0, #T_2e53c_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_2e53c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e53c_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_2e53c_row0_col0" class="data row0 col0" >how long has it been since you review the objectives of your benefit and savice programme</td>
#       <td id="T_2e53c_row0_col1" class="data row0 col1" >0.187500</td>
#     </tr>
#     <tr>
#       <th id="T_2e53c_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_2e53c_row1_col0" class="data row1 col0" >how long has it been since you reviewed the objectives of your benefit and sevis programm</td>
#       <td id="T_2e53c_row1_col1" class="data row1 col1" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_2e53c_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_2e53c_row2_col0" class="data row2 col0" >how long has it been since you review the objectives of your benefit and service program</td>
#       <td id="T_2e53c_row2_col1" class="data row2 col1" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_2e53c_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_2e53c_row3_col0" class="data row3 col0" >how long has it been since you reviewed the objectives of your benefit and service programme</td>
#       <td id="T_2e53c_row3_col1" class="data row3 col1" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_2e53c_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_2e53c_row4_col0" class="data row4 col0" >how long has it been since you reviewed the objectives of your benefit and service program </td>
#       <td id="T_2e53c_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[1])
show_semcor_transcriptions_comparison(outs[1])
# Out:
# {8: ('program', ['programm', 'giveaway']),
#  12: ('that', ['there', 'one']),
#  13: ('has', ['as', 'there']),
#  18: ('employee', ['emploimoral', 'improved']),
#  19: ('morale', ['and', 'emploimoral'])}
# <style type="text/css">
# #T_60a70_row0_col0, #T_60a70_row0_col1, #T_60a70_row1_col0, #T_60a70_row1_col1, #T_60a70_row2_col0, #T_60a70_row2_col1, #T_60a70_row3_col0, #T_60a70_row3_col1, #T_60a70_row4_col0, #T_60a70_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_60a70_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60a70_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_60a70_row0_col0" class="data row0 col0" >have you permitted it to become a give away programm rather than one that as the go of improving pluymoral and consequently increase productivity</td>
#       <td id="T_60a70_row0_col1" class="data row0 col1" >0.375000</td>
#     </tr>
#     <tr>
#       <th id="T_60a70_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_60a70_row1_col0" class="data row1 col0" >have you permitted it to become a giveaway programm rather than one that as the goal of improved impluimoral and consequently increase productivity</td>
#       <td id="T_60a70_row1_col1" class="data row1 col1" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_60a70_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_60a70_row2_col0" class="data row2 col0" >evew permitted it to become a giveaway program rather than one that as the goal of improved employee morile and consequently increased productivity</td>
#       <td id="T_60a70_row2_col1" class="data row2 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_60a70_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_60a70_row3_col0" class="data row3 col0" >have you permitted it to become a giveaway programm rather than one there as the goal of improved emploimoral and consequently increased productivity</td>
#       <td id="T_60a70_row3_col1" class="data row3 col1" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_60a70_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_60a70_row4_col0" class="data row4 col0" >have you permitted it to become a giveaway program rather than one that has the goal of improved employee morale and  consequently  increased productivity </td>
#       <td id="T_60a70_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[2])
show_semcor_transcriptions_comparison(outs[2])
# Out:
# {10: ('program', ['programme', 'programme'])}
# <style type="text/css">
# #T_c71fb_row0_col0, #T_c71fb_row0_col1, #T_c71fb_row1_col0, #T_c71fb_row1_col1, #T_c71fb_row2_col0, #T_c71fb_row2_col1, #T_c71fb_row3_col0, #T_c71fb_row3_col1, #T_c71fb_row4_col0, #T_c71fb_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c71fb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c71fb_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_c71fb_row0_col0" class="data row0 col0" >what effort do you make to assess results of your programme</td>
#       <td id="T_c71fb_row0_col1" class="data row0 col1" >0.090909</td>
#     </tr>
#     <tr>
#       <th id="T_c71fb_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_c71fb_row1_col0" class="data row1 col0" >what effort do you make to assess results of your programme</td>
#       <td id="T_c71fb_row1_col1" class="data row1 col1" >0.090909</td>
#     </tr>
#     <tr>
#       <th id="T_c71fb_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_c71fb_row2_col0" class="data row2 col0" >what effort do you make to assess results of your program</td>
#       <td id="T_c71fb_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c71fb_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_c71fb_row3_col0" class="data row3 col0" >what effort do you make to assess results of your programme</td>
#       <td id="T_c71fb_row3_col1" class="data row3 col1" >0.090909</td>
#     </tr>
#     <tr>
#       <th id="T_c71fb_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_c71fb_row4_col0" class="data row4 col0" >what effort do you make to assess results of your program </td>
#       <td id="T_c71fb_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[3])
show_semcor_transcriptions_comparison(outs[3])
# Out:
# {6: ('reduced', ['reduce', 'absentism']),
#  7: ('absenteeism', ['absentism', 'turn']),
#  8: ('turnover', ['turn', 'over']),
#  14: ('improved', ['to', 'improve'])}
# <style type="text/css">
# #T_7760f_row0_col0, #T_7760f_row0_col1, #T_7760f_row1_col0, #T_7760f_row1_col1, #T_7760f_row2_col0, #T_7760f_row2_col1, #T_7760f_row3_col0, #T_7760f_row3_col1, #T_7760f_row4_col0, #T_7760f_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_7760f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7760f_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_7760f_row0_col0" class="data row0 col0" >do you measure its relation to reduce absentiism turnover accidents and grievances and to improve quality and output</td>
#       <td id="T_7760f_row0_col1" class="data row0 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_7760f_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_7760f_row1_col0" class="data row1 col0" >do you measure its relation to reduce abzentism turnover accidents and grievances and to improve quality and output</td>
#       <td id="T_7760f_row1_col1" class="data row1 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_7760f_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_7760f_row2_col0" class="data row2 col0" >do you measure its relation to reduce absenteism tarnover accidents angrievences and to improve quality and output</td>
#       <td id="T_7760f_row2_col1" class="data row2 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_7760f_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_7760f_row3_col0" class="data row3 col0" >do you measure its relation to reduce absentism turn over accidents and grievances and to improve quality and output</td>
#       <td id="T_7760f_row3_col1" class="data row3 col1" >0.277778</td>
#     </tr>
#     <tr>
#       <th id="T_7760f_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_7760f_row4_col0" class="data row4 col0" >do you measure its relation to reduced absenteeism  turnover  accidents  and grievances  and to improved quality and output </td>
#       <td id="T_7760f_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[4])
show_semcor_transcriptions_comparison(outs[4])
# Out:
# {2: ('set', ['sad', 'sad']), 7: ('employee', ['emploe', 'emploe'])}
# <style type="text/css">
# #T_68e37_row0_col0, #T_68e37_row0_col1, #T_68e37_row1_col0, #T_68e37_row1_col1, #T_68e37_row2_col0, #T_68e37_row2_col1, #T_68e37_row3_col0, #T_68e37_row3_col1, #T_68e37_row4_col0, #T_68e37_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_68e37_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68e37_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_68e37_row0_col0" class="data row0 col0" >have you said specific objectives for your implite obligation</td>
#       <td id="T_68e37_row0_col1" class="data row0 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_68e37_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_68e37_row1_col0" class="data row1 col0" >have you sad specific objectives for your employed publication</td>
#       <td id="T_68e37_row1_col1" class="data row1 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_68e37_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_68e37_row2_col0" class="data row2 col0" >have you sad specific objectives for your employee publication</td>
#       <td id="T_68e37_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_68e37_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_68e37_row3_col0" class="data row3 col0" >have you sad specific objectives for your emploe publication</td>
#       <td id="T_68e37_row3_col1" class="data row3 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_68e37_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_68e37_row4_col0" class="data row4 col0" >have you set specific objectives for your employee publication </td>
#       <td id="T_68e37_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[5])
show_semcor_transcriptions_comparison(outs[5])
# Out:
# {}
# <style type="text/css">
# #T_32391_row0_col0, #T_32391_row0_col1, #T_32391_row1_col0, #T_32391_row1_col1, #T_32391_row2_col0, #T_32391_row2_col1, #T_32391_row3_col0, #T_32391_row3_col1, #T_32391_row4_col0, #T_32391_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_32391_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32391_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_32391_row0_col0" class="data row0 col0" >is it reaching these goals</td>
#       <td id="T_32391_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32391_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_32391_row1_col0" class="data row1 col0" >is it reaching these goals</td>
#       <td id="T_32391_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32391_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_32391_row2_col0" class="data row2 col0" >is it reaching these goals</td>
#       <td id="T_32391_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32391_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_32391_row3_col0" class="data row3 col0" >is it reaching these goals</td>
#       <td id="T_32391_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32391_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_32391_row4_col0" class="data row4 col0" >is it reaching these goals </td>
#       <td id="T_32391_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[6])
show_semcor_transcriptions_comparison(outs[6])
# Out:
# {3: ('or', ['offence', 'offence']), 4: ('fancier', ['ere', 'ere'])}
# <style type="text/css">
# #T_b9bfb_row0_col0, #T_b9bfb_row0_col1, #T_b9bfb_row1_col0, #T_b9bfb_row1_col1, #T_b9bfb_row2_col0, #T_b9bfb_row2_col1, #T_b9bfb_row3_col0, #T_b9bfb_row3_col1, #T_b9bfb_row4_col0, #T_b9bfb_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b9bfb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9bfb_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_b9bfb_row0_col0" class="data row0 col0" >is it larger offencier than you really need</td>
#       <td id="T_b9bfb_row0_col1" class="data row0 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_b9bfb_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_b9bfb_row1_col0" class="data row1 col0" >is it larger or fancier than you really need</td>
#       <td id="T_b9bfb_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b9bfb_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_b9bfb_row2_col0" class="data row2 col0" >is it larger ofencier than you really need</td>
#       <td id="T_b9bfb_row2_col1" class="data row2 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_b9bfb_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_b9bfb_row3_col0" class="data row3 col0" >is it larger offence ere than you really need</td>
#       <td id="T_b9bfb_row3_col1" class="data row3 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_b9bfb_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_b9bfb_row4_col0" class="data row4 col0" >is it larger or fancier than you really need </td>
#       <td id="T_b9bfb_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[7])
show_semcor_transcriptions_comparison(outs[7])
# Out:
# {9: ('etc', ['et', 'cetera'])}
# <style type="text/css">
# #T_1f71a_row0_col0, #T_1f71a_row0_col1, #T_1f71a_row1_col0, #T_1f71a_row1_col1, #T_1f71a_row2_col0, #T_1f71a_row2_col1, #T_1f71a_row3_col0, #T_1f71a_row3_col1, #T_1f71a_row4_col0, #T_1f71a_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_1f71a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f71a_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_1f71a_row0_col0" class="data row0 col0" >are you using the most economical printing methods paper et cetera</td>
#       <td id="T_1f71a_row0_col1" class="data row0 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_1f71a_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_1f71a_row1_col0" class="data row1 col0" >are you using the most economical printing methods paper et cetera</td>
#       <td id="T_1f71a_row1_col1" class="data row1 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_1f71a_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_1f71a_row2_col0" class="data row2 col0" >are you using the most economical printing methods paper exce</td>
#       <td id="T_1f71a_row2_col1" class="data row2 col1" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_1f71a_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_1f71a_row3_col0" class="data row3 col0" >are you using the most economical printing methods paper et cetera</td>
#       <td id="T_1f71a_row3_col1" class="data row3 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_1f71a_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_1f71a_row4_col0" class="data row4 col0" >are you using the most economical printing methods  paper  etc </td>
#       <td id="T_1f71a_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[8])
show_semcor_transcriptions_comparison(outs[8])
# Out:
# {}
# <style type="text/css">
# #T_2ce8d_row0_col0, #T_2ce8d_row0_col1, #T_2ce8d_row1_col0, #T_2ce8d_row1_col1, #T_2ce8d_row2_col0, #T_2ce8d_row2_col1, #T_2ce8d_row3_col0, #T_2ce8d_row3_col1, #T_2ce8d_row4_col0, #T_2ce8d_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_2ce8d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ce8d_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_2ce8d_row0_col0" class="data row0 col0" >are there ar there are cheaper communications thechniques that could be substituted</td>
#       <td id="T_2ce8d_row0_col1" class="data row0 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_2ce8d_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_2ce8d_row1_col0" class="data row1 col0" >are there other cheaper communications techniques that could be substituted</td>
#       <td id="T_2ce8d_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2ce8d_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_2ce8d_row2_col0" class="data row2 col0" >are there other cheaper communications techniques that could be substituted</td>
#       <td id="T_2ce8d_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2ce8d_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_2ce8d_row3_col0" class="data row3 col0" >are there other cheaper communications techniques that could be substituted</td>
#       <td id="T_2ce8d_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2ce8d_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_2ce8d_row4_col0" class="data row4 col0" >are there other  cheaper communications techniques that could be substituted </td>
#       <td id="T_2ce8d_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[9])
show_semcor_transcriptions_comparison(outs[9])
# Out:
# {4: ('employee', ['employe', 'employe'])}
# <style type="text/css">
# #T_48841_row0_col0, #T_48841_row0_col1, #T_48841_row1_col0, #T_48841_row1_col1, #T_48841_row2_col0, #T_48841_row2_col1, #T_48841_row3_col0, #T_48841_row3_col1, #T_48841_row4_col0, #T_48841_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_48841_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48841_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_48841_row0_col0" class="data row0 col0" >has your attitude toward in ple benefits in corage and excess of free government work in your plant</td>
#       <td id="T_48841_row0_col1" class="data row0 col1" >0.312500</td>
#     </tr>
#     <tr>
#       <th id="T_48841_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_48841_row1_col0" class="data row1 col0" >has your attitude toward him thlee benefits encouraged an excess of free government work in your plant</td>
#       <td id="T_48841_row1_col1" class="data row1 col1" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_48841_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_48841_row2_col0" class="data row2 col0" >has your attitude toward employee benefits encouraged an excess of free government war in your plant</td>
#       <td id="T_48841_row2_col1" class="data row2 col1" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_48841_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_48841_row3_col0" class="data row3 col0" >has your attitude toward employe benefits encouraged an excess of free government work in your plant</td>
#       <td id="T_48841_row3_col1" class="data row3 col1" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_48841_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_48841_row4_col0" class="data row4 col0" >has your attitude toward employee benefits encouraged an excess of free  government  work in your plant </td>
#       <td id="T_48841_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[10])
show_semcor_transcriptions_comparison(outs[10])
# Out:
# {11: ('employees', ['employes', 'employes'])}
# <style type="text/css">
# #T_466a4_row0_col0, #T_466a4_row0_col1, #T_466a4_row1_col0, #T_466a4_row1_col1, #T_466a4_row2_col0, #T_466a4_row2_col1, #T_466a4_row3_col0, #T_466a4_row3_col1, #T_466a4_row4_col0, #T_466a4_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_466a4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_466a4_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_466a4_row0_col0" class="data row0 col0" >easier purchasing agent offering too much frebuying service for the please</td>
#       <td id="T_466a4_row0_col1" class="data row0 col1" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_466a4_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_466a4_row1_col0" class="data row1 col0" >easier purchasing agent offering too much free buying service for him please</td>
#       <td id="T_466a4_row1_col1" class="data row1 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_466a4_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_466a4_row2_col0" class="data row2 col0" >is your purchasing agent offering too much free buying service for employees</td>
#       <td id="T_466a4_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_466a4_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_466a4_row3_col0" class="data row3 col0" >is your purchasing agent offering too much free buying service for employes</td>
#       <td id="T_466a4_row3_col1" class="data row3 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_466a4_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_466a4_row4_col0" class="data row4 col0" >is your purchasing agent offering too much free buying service for employees </td>
#       <td id="T_466a4_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[11])
show_semcor_transcriptions_comparison(outs[11])
# Out:
# {9: ('lighting', ['lightning', 'rest']),
#  14: ('airconditioning', ['air', 'conditioning'])}
# <style type="text/css">
# #T_7eb88_row0_col0, #T_7eb88_row0_col1, #T_7eb88_row1_col0, #T_7eb88_row1_col1, #T_7eb88_row2_col0, #T_7eb88_row2_col1, #T_7eb88_row3_col0, #T_7eb88_row3_col1, #T_7eb88_row4_col0, #T_7eb88_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_7eb88_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eb88_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_7eb88_row0_col0" class="data row0 col0" >when improvements are recommended in working conditions such as lightning rest rooms eating facilities eir conditioning do you try to set a measure of their effactiveness on productivity</td>
#       <td id="T_7eb88_row0_col1" class="data row0 col1" >0.148148</td>
#     </tr>
#     <tr>
#       <th id="T_7eb88_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_7eb88_row1_col0" class="data row1 col0" >when improvements are recommended in working conditions such as lighting rest rooms eating facilities air conditioning do you try to set a measure of their effectiveness on productivity</td>
#       <td id="T_7eb88_row1_col1" class="data row1 col1" >0.074074</td>
#     </tr>
#     <tr>
#       <th id="T_7eb88_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_7eb88_row2_col0" class="data row2 col0" >when improvements are recommended in working conditions such as lighting restrooms eating facilities air-conditioning do you try to set a measure of their effectiveness on productivity</td>
#       <td id="T_7eb88_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_7eb88_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_7eb88_row3_col0" class="data row3 col0" >when improvements are recommended in working conditions such as lightning rest rooms eating facilities air conditioning do you try to set a measure of their effectiveness on productivity</td>
#       <td id="T_7eb88_row3_col1" class="data row3 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_7eb88_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_7eb88_row4_col0" class="data row4 col0" >when improvements are recommended in working conditions  such as lighting  rest rooms  eating facilities  airconditioning  do you try to set a measure of their effectiveness on productivity </td>
#       <td id="T_7eb88_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[12])
show_semcor_transcriptions_comparison(outs[12])
# Out:
# <style type="text/css">
# #T_0ee80_row0_col0, #T_0ee80_row0_col1, #T_0ee80_row1_col0, #T_0ee80_row1_col1, #T_0ee80_row2_col0, #T_0ee80_row2_col1, #T_0ee80_row3_col0, #T_0ee80_row3_col1, #T_0ee80_row4_col0, #T_0ee80_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_0ee80_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ee80_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_0ee80_row0_col0" class="data row0 col0" >when negotiating with your union do you make sure imploase a vachalways between new benefits and their sense petour costing wages</td>
#       <td id="T_0ee80_row0_col1" class="data row0 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_0ee80_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_0ee80_row1_col0" class="data row1 col0" >when negotiating with your union do you make sure emplois evathois between new benefits and their scense bet our costing wages</td>
#       <td id="T_0ee80_row1_col1" class="data row1 col1" >0.375000</td>
#     </tr>
#     <tr>
#       <th id="T_0ee80_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_0ee80_row2_col0" class="data row2 col0" >when negotiating with your union do you make sure employees ava choise between new benefits and their sanspit-hour costing wages</td>
#       <td id="T_0ee80_row2_col1" class="data row2 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_0ee80_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_0ee80_row3_col0" class="data row3 col0" >when negotiating with your union do you make sure employees have a choice between new benefits and their cents pay our costing wages</td>
#       <td id="T_0ee80_row3_col1" class="data row3 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_0ee80_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_0ee80_row4_col0" class="data row4 col0" >when negotiating with your union  do you make sure employees have a choice between new benefits and their cents per hour cost in wages </td>
#       <td id="T_0ee80_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
# slow = get_semcor_sample_transcriptions(sample_idx=12, path=f"{SEMCOR_SPEECH_PATH}mothertongue/", postfix="-slow")
show_semcor_transcriptions_comparison(slow)
# Out:
# <style type="text/css">
# #T_6a308_row0_col0, #T_6a308_row0_col1, #T_6a308_row1_col0, #T_6a308_row1_col1, #T_6a308_row2_col0, #T_6a308_row2_col1, #T_6a308_row3_col0, #T_6a308_row3_col1, #T_6a308_row4_col0, #T_6a308_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_6a308_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a308_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_6a308_row0_col0" class="data row0 col0" >when negotiating with your union do you make sure employs have a choice between new benefits and their cense for our costine wages</td>
#       <td id="T_6a308_row0_col1" class="data row0 col1" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_6a308_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_6a308_row1_col0" class="data row1 col0" >when negotiating with your union do you make sure employers have a choice between new benefits and their scents por our costline wages</td>
#       <td id="T_6a308_row1_col1" class="data row1 col1" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_6a308_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_6a308_row2_col0" class="data row2 col0" >when negotiating with your union do you make sure employees have a choice between new benefits ome their cense-parou costing wages</td>
#       <td id="T_6a308_row2_col1" class="data row2 col1" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_6a308_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_6a308_row3_col0" class="data row3 col0" >when negotiating with your union do you make sure employes have a choice between new benefits and their cents per hour cost in wages</td>
#       <td id="T_6a308_row3_col1" class="data row3 col1" >0.041667</td>
#     </tr>
#     <tr>
#       <th id="T_6a308_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_6a308_row4_col0" class="data row4 col0" >when negotiating with your union  do you make sure employees have a choice between new benefits and their cents per hour cost in wages </td>
#       <td id="T_6a308_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
# fast = get_semcor_sample_transcriptions(sample_idx=12, path=f"{SEMCOR_SPEECH_PATH}mothertongue/", postfix="-fast")
show_semcor_transcriptions_comparison(fast)
# Out:
# <style type="text/css">
# #T_a0099_row0_col0, #T_a0099_row0_col1, #T_a0099_row1_col0, #T_a0099_row1_col1, #T_a0099_row2_col0, #T_a0099_row2_col1, #T_a0099_row3_col0, #T_a0099_row3_col1, #T_a0099_row4_col0, #T_a0099_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a0099_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0099_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_a0099_row0_col0" class="data row0 col0" >when negotiating with your union do you make sure employes have the choice between new benefits and their cents per hour cost in wages</td>
#       <td id="T_a0099_row0_col1" class="data row0 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_a0099_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_a0099_row1_col0" class="data row1 col0" >when negotiating with your union do you make sure employes have a choice between new benefits and their scense paraur cost in wages</td>
#       <td id="T_a0099_row1_col1" class="data row1 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_a0099_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_a0099_row2_col0" class="data row2 col0" >when negotiating with your uniondo you make sure employees have a choice between new benefits and their sense-peraur cost in wages</td>
#       <td id="T_a0099_row2_col1" class="data row2 col1" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_a0099_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_a0099_row3_col0" class="data row3 col0" >when negotiating with your union do you make sure employees have a choice between new benefits and their cents per hour cost in wages</td>
#       <td id="T_a0099_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a0099_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_a0099_row4_col0" class="data row4 col0" >when negotiating with your union  do you make sure employees have a choice between new benefits and their cents per hour cost in wages </td>
#       <td id="T_a0099_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[13])
show_semcor_transcriptions_comparison(outs[13])

# %%
pprint(wrongs_list[14])
show_semcor_transcriptions_comparison(outs[14])
# Out:
# {2: ('employees', ['employies', 'employies'])}
# <style type="text/css">
# #T_9bca6_row0_col0, #T_9bca6_row0_col1, #T_9bca6_row1_col0, #T_9bca6_row1_col1, #T_9bca6_row2_col0, #T_9bca6_row2_col1, #T_9bca6_row3_col0, #T_9bca6_row3_col1, #T_9bca6_row4_col0, #T_9bca6_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_9bca6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bca6_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_9bca6_row0_col0" class="data row0 col0" >do your in please understand all the benefits to which your insurance entitles them</td>
#       <td id="T_9bca6_row0_col1" class="data row0 col1" >0.153846</td>
#     </tr>
#     <tr>
#       <th id="T_9bca6_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_9bca6_row1_col0" class="data row1 col0" >do your emplis understand all the benefits to which your insurance entitles them</td>
#       <td id="T_9bca6_row1_col1" class="data row1 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_9bca6_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_9bca6_row2_col0" class="data row2 col0" >do your employeese understandl the benefits to which your insurance entitles them</td>
#       <td id="T_9bca6_row2_col1" class="data row2 col1" >0.230769</td>
#     </tr>
#     <tr>
#       <th id="T_9bca6_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_9bca6_row3_col0" class="data row3 col0" >do your employies understand all the benefits to which your insurance entitles them</td>
#       <td id="T_9bca6_row3_col1" class="data row3 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_9bca6_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_9bca6_row4_col0" class="data row4 col0" >do your employees understand all the benefits to which your insurance entitles them </td>
#       <td id="T_9bca6_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[15])
show_semcor_transcriptions_comparison(outs[15])
# Out:
# {}
# <style type="text/css">
# #T_6bcc2_row0_col0, #T_6bcc2_row0_col1, #T_6bcc2_row1_col0, #T_6bcc2_row1_col1, #T_6bcc2_row2_col0, #T_6bcc2_row2_col1, #T_6bcc2_row3_col0, #T_6bcc2_row3_col1, #T_6bcc2_row4_col0, #T_6bcc2_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_6bcc2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bcc2_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_6bcc2_row0_col0" class="data row0 col0" >are they incourage to take full legal advantage of these benefits</td>
#       <td id="T_6bcc2_row0_col1" class="data row0 col1" >0.090909</td>
#     </tr>
#     <tr>
#       <th id="T_6bcc2_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_6bcc2_row1_col0" class="data row1 col0" >are they encouraged to take full legal advantage of these benefits</td>
#       <td id="T_6bcc2_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bcc2_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_6bcc2_row2_col0" class="data row2 col0" >are they encouraged to take full legal advantage of these benefits</td>
#       <td id="T_6bcc2_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bcc2_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_6bcc2_row3_col0" class="data row3 col0" >are they encouraged to take full legal advantage of these benefits</td>
#       <td id="T_6bcc2_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bcc2_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_6bcc2_row4_col0" class="data row4 col0" >are they encouraged to take full legal advantage of these benefits </td>
#       <td id="T_6bcc2_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[16])
show_semcor_transcriptions_comparison(outs[16])
# Out:
# {10: ('company', ["company's", 'the']), 11: ('s', ['share', "company's"])}
# <style type="text/css">
# #T_83af9_row0_col0, #T_83af9_row0_col1, #T_83af9_row1_col0, #T_83af9_row1_col1, #T_83af9_row2_col0, #T_83af9_row2_col1, #T_83af9_row3_col0, #T_83af9_row3_col1, #T_83af9_row4_col0, #T_83af9_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_83af9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83af9_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_83af9_row0_col0" class="data row0 col0" >ave youco besides the sensperour value of the company's share of insuranspeniums</td>
#       <td id="T_83af9_row0_col1" class="data row0 col1" >0.625000</td>
#     </tr>
#     <tr>
#       <th id="T_83af9_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_83af9_row1_col0" class="data row1 col0" >evieupublicize the sensperaor value of the company's share of insurance premins</td>
#       <td id="T_83af9_row1_col1" class="data row1 col1" >0.562500</td>
#     </tr>
#     <tr>
#       <th id="T_83af9_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_83af9_row2_col0" class="data row2 col0" >have you publicize the sensper-hour value of the company's share of insurance premiums</td>
#       <td id="T_83af9_row2_col1" class="data row2 col1" >0.375000</td>
#     </tr>
#     <tr>
#       <th id="T_83af9_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_83af9_row3_col0" class="data row3 col0" >have you publicized the cents per hour value of the company's share of insurance premiums</td>
#       <td id="T_83af9_row3_col1" class="data row3 col1" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_83af9_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_83af9_row4_col0" class="data row4 col0" >have you publicized the cents per hour value of the company s share of insurance premiums </td>
#       <td id="T_83af9_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[17])
show_semcor_transcriptions_comparison(outs[17])
# Out:
# {}
# <style type="text/css">
# #T_380fe_row0_col0, #T_380fe_row0_col1, #T_380fe_row1_col0, #T_380fe_row1_col1, #T_380fe_row2_col0, #T_380fe_row2_col1, #T_380fe_row3_col0, #T_380fe_row3_col1, #T_380fe_row4_col0, #T_380fe_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_380fe_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_380fe_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_380fe_row0_col0" class="data row0 col0" >when did you lust compare your present preaming costs with the costs of insurence from other sources</td>
#       <td id="T_380fe_row0_col1" class="data row0 col1" >0.176471</td>
#     </tr>
#     <tr>
#       <th id="T_380fe_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_380fe_row1_col0" class="data row1 col0" >when did you lust compare your present premien costs with the costs of insurance from other sources</td>
#       <td id="T_380fe_row1_col1" class="data row1 col1" >0.117647</td>
#     </tr>
#     <tr>
#       <th id="T_380fe_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_380fe_row2_col0" class="data row2 col0" >when did you last compare your present premium costs with the costs of insurance from other sources</td>
#       <td id="T_380fe_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_380fe_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_380fe_row3_col0" class="data row3 col0" >when did you last compare your present premium costs with the costs of insurance from other sources</td>
#       <td id="T_380fe_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_380fe_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_380fe_row4_col0" class="data row4 col0" >when did you last compare your present premium costs with the costs of insurance from other sources </td>
#       <td id="T_380fe_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[18])
show_semcor_transcriptions_comparison(outs[18])
# Out:
# {}
# <style type="text/css">
# #T_99d52_row0_col0, #T_99d52_row0_col1, #T_99d52_row1_col0, #T_99d52_row1_col1, #T_99d52_row2_col0, #T_99d52_row2_col1, #T_99d52_row3_col0, #T_99d52_row3_col1, #T_99d52_row4_col0, #T_99d52_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_99d52_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99d52_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_99d52_row0_col0" class="data row0 col0" >can your insurance company aid you in reducing administrative costs</td>
#       <td id="T_99d52_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99d52_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_99d52_row1_col0" class="data row1 col0" >can your insurance company aid you in reducing administrative costs</td>
#       <td id="T_99d52_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99d52_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_99d52_row2_col0" class="data row2 col0" >can your insurance company aid you in reducing administrative costs</td>
#       <td id="T_99d52_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99d52_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_99d52_row3_col0" class="data row3 col0" >can your insurance company aid you in reducing administrative costs</td>
#       <td id="T_99d52_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99d52_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_99d52_row4_col0" class="data row4 col0" >can your insurance company aid you in reducing administrative costs </td>
#       <td id="T_99d52_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[19])
show_semcor_transcriptions_comparison(outs[19])
# Out:
# {8: ('employee', ['imply', 'imply'])}
# <style type="text/css">
# #T_34523_row0_col0, #T_34523_row0_col1, #T_34523_row1_col0, #T_34523_row1_col1, #T_34523_row2_col0, #T_34523_row2_col1, #T_34523_row3_col0, #T_34523_row3_col1, #T_34523_row4_col0, #T_34523_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_34523_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34523_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_34523_row0_col0" class="data row0 col0" >do you try to maintain the principle of implecontributed as opposto fully company paid programms</td>
#       <td id="T_34523_row0_col1" class="data row0 col1" >0.294118</td>
#     </tr>
#     <tr>
#       <th id="T_34523_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_34523_row1_col0" class="data row1 col0" >do you try to maintain the principle of imply contributed as opposed to fully companypaid programms</td>
#       <td id="T_34523_row1_col1" class="data row1 col1" >0.235294</td>
#     </tr>
#     <tr>
#       <th id="T_34523_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_34523_row2_col0" class="data row2 col0" >do you try to maintain the principle of employe contributed as opposed to fully company-paid programs</td>
#       <td id="T_34523_row2_col1" class="data row2 col1" >0.176471</td>
#     </tr>
#     <tr>
#       <th id="T_34523_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_34523_row3_col0" class="data row3 col0" >do you try to maintain the principle of imply contributed as opposed to fully company paid programs</td>
#       <td id="T_34523_row3_col1" class="data row3 col1" >0.058824</td>
#     </tr>
#     <tr>
#       <th id="T_34523_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_34523_row4_col0" class="data row4 col0" >do you try to maintain the principle of employee contributed  as opposed to fully company paid  programs </td>
#       <td id="T_34523_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[20])
show_semcor_transcriptions_comparison(outs[20])
# Out:
# {}
# <style type="text/css">
# #T_90410_row0_col0, #T_90410_row0_col1, #T_90410_row1_col0, #T_90410_row1_col1, #T_90410_row2_col0, #T_90410_row2_col1, #T_90410_row3_col0, #T_90410_row3_col1, #T_90410_row4_col0, #T_90410_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_90410_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90410_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_90410_row0_col0" class="data row0 col0" >do you protect your holiday privileges with an attendanc' requirement both before and after the holiday</td>
#       <td id="T_90410_row0_col1" class="data row0 col1" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_90410_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_90410_row1_col0" class="data row1 col0" >do you protect your holiday privileges with an attendance requirement both before and after the holiday</td>
#       <td id="T_90410_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90410_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_90410_row2_col0" class="data row2 col0" >do you protect your holiday privileges with an attendance requirement both before and after the holiday</td>
#       <td id="T_90410_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90410_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_90410_row3_col0" class="data row3 col0" >do you protect your holiday privileges with an attendance requirement both before and after the holiday</td>
#       <td id="T_90410_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90410_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_90410_row4_col0" class="data row4 col0" >do you protect your holiday privileges with an attendance requirement both before and after the holiday </td>
#       <td id="T_90410_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[21])
show_semcor_transcriptions_comparison(outs[21])
# Out:
# {4: ('limit', ['lein', 'its'])}
# <style type="text/css">
# #T_0165f_row0_col0, #T_0165f_row0_col1, #T_0165f_row1_col0, #T_0165f_row1_col1, #T_0165f_row2_col0, #T_0165f_row2_col1, #T_0165f_row3_col0, #T_0165f_row3_col1, #T_0165f_row4_col0, #T_0165f_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_0165f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0165f_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_0165f_row0_col0" class="data row0 col0" >do you plan to lean its additional olidays to area and orindustrial patterns</td>
#       <td id="T_0165f_row0_col1" class="data row0 col1" >0.384615</td>
#     </tr>
#     <tr>
#       <th id="T_0165f_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_0165f_row1_col0" class="data row1 col0" >do you plan to lenets additional holidays to area and or industrial patterns</td>
#       <td id="T_0165f_row1_col1" class="data row1 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_0165f_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_0165f_row2_col0" class="data row2 col0" >do you plan to limit aditional holidays to area and or industrial patterns</td>
#       <td id="T_0165f_row2_col1" class="data row2 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_0165f_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_0165f_row3_col0" class="data row3 col0" >do you plan to lein its additional holidays to area and or industrial patterns</td>
#       <td id="T_0165f_row3_col1" class="data row3 col1" >0.153846</td>
#     </tr>
#     <tr>
#       <th id="T_0165f_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_0165f_row4_col0" class="data row4 col0" >do you plan to limit additional holidays to area and  or industrial patterns </td>
#       <td id="T_0165f_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[22])
show_semcor_transcriptions_comparison(outs[22])
# Out:
# {22: ('work', ['workweek', 'uninterrupted']), 23: ('week', ['', 'workweek'])}
# <style type="text/css">
# #T_e8e46_row0_col0, #T_e8e46_row0_col1, #T_e8e46_row1_col0, #T_e8e46_row1_col1, #T_e8e46_row2_col0, #T_e8e46_row2_col1, #T_e8e46_row3_col0, #T_e8e46_row3_col1, #T_e8e46_row4_col0, #T_e8e46_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e8e46_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8e46_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_e8e46_row0_col0" class="data row0 col0" >have you investigated the possibility of moving midwak hollidays forward to monday or back to friday in order to have an uninterrupted workwik</td>
#       <td id="T_e8e46_row0_col1" class="data row0 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_e8e46_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_e8e46_row1_col0" class="data row1 col0" >have you investigated the possibility of moving midwick holidays forward to monday or back to friday in order to avan uninterrupted workwick</td>
#       <td id="T_e8e46_row1_col1" class="data row1 col1" >0.208333</td>
#     </tr>
#     <tr>
#       <th id="T_e8e46_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_e8e46_row2_col0" class="data row2 col0" >have you investigated the possibility of moving midwak holidays forward to monday or back to friday in order to have an uninterrupted workweek</td>
#       <td id="T_e8e46_row2_col1" class="data row2 col1" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_e8e46_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_e8e46_row3_col0" class="data row3 col0" >have you investigated the possibility of moving midweek holidays forward to monday or back to friday in order to have an uninterrupted workweek</td>
#       <td id="T_e8e46_row3_col1" class="data row3 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_e8e46_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_e8e46_row4_col0" class="data row4 col0" >have you investigated the possibility of moving midweek holidays forward to monday or back to friday in order to have an uninterrupted work week </td>
#       <td id="T_e8e46_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[23])
show_semcor_transcriptions_comparison(outs[23])
# Out:
# {3: ('policing', ['polising', 'polising']), 4: ('washup', ['washp', 'washp'])}
# <style type="text/css">
# #T_79788_row0_col0, #T_79788_row0_col1, #T_79788_row1_col0, #T_79788_row1_col1, #T_79788_row2_col0, #T_79788_row2_col1, #T_79788_row3_col0, #T_79788_row3_col1, #T_79788_row4_col0, #T_79788_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_79788_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79788_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_79788_row0_col0" class="data row0 col0" >are you carefully polishing woodshop time and resperious to be certain that all other time is prolactive</td>
#       <td id="T_79788_row0_col1" class="data row0 col1" >0.277778</td>
#     </tr>
#     <tr>
#       <th id="T_79788_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_79788_row1_col0" class="data row1 col0" >are you carefully polishing worshop time and rasperius to be certain that all other time is productive</td>
#       <td id="T_79788_row1_col1" class="data row1 col1" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_79788_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_79788_row2_col0" class="data row2 col0" >are you carefully polishing wushup time and rest periods to be certain that all other time is productive</td>
#       <td id="T_79788_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_79788_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_79788_row3_col0" class="data row3 col0" >are you carefully polising washp time and rest periods to be certain that all other time is productive</td>
#       <td id="T_79788_row3_col1" class="data row3 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_79788_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_79788_row4_col0" class="data row4 col0" >are you carefully policing washup time and rest periods to be certain that all other time is productive </td>
#       <td id="T_79788_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
pprint(wrongs_list[24])
show_semcor_transcriptions_comparison(outs[24])
# Out:
# {3: ('work', ['worse', 'caduales']),
#  4: ('schedules', ['caduales', 'for']),
#  6: ('boiler', ['boleberators', 'guard']),
#  7: ('operators', ['guard', 'and']),
#  8: ('guards', ['and', 'other']),
#  9: ('and', ['other', 'twenty']),
#  10: ('other', ['twenty', 'four']),
#  11: ('24', ['four', 'hour']),
#  14: ('7', ['seven', 'day']),
#  22: ('overtime', ['over', 'time'])}
# <style type="text/css">
# #T_b0d55_row0_col0, #T_b0d55_row0_col1, #T_b0d55_row1_col0, #T_b0d55_row1_col1, #T_b0d55_row2_col0, #T_b0d55_row2_col1, #T_b0d55_row3_col0, #T_b0d55_row3_col1, #T_b0d55_row4_col0, #T_b0d55_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b0d55_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0d55_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_b0d55_row0_col0" class="data row0 col0" >are you watching worse caduls for bottelbrators guards another or twenty four our day seven they week overations in order to minimasere time</td>
#       <td id="T_b0d55_row0_col1" class="data row0 col1" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_b0d55_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_b0d55_row1_col0" class="data row1 col0" >are you watching worse caduals for bolerberators guards another or twenty four hour day seven day week operations in order to manymiles over time</td>
#       <td id="T_b0d55_row1_col1" class="data row1 col1" >0.521739</td>
#     </tr>
#     <tr>
#       <th id="T_b0d55_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_b0d55_row2_col0" class="data row2 col0" >are you watching word schedules for bull operators guards and other twenty-for-hour-day seven-dayweek oporations in order to minimize over time</td>
#       <td id="T_b0d55_row2_col1" class="data row2 col1" >0.478261</td>
#     </tr>
#     <tr>
#       <th id="T_b0d55_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_b0d55_row3_col0" class="data row3 col0" >are you watching worse caduales for boleberators guard and other twenty four hour day seven day week operations in order to minimize over time</td>
#       <td id="T_b0d55_row3_col1" class="data row3 col1" >0.434783</td>
#     </tr>
#     <tr>
#       <th id="T_b0d55_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_b0d55_row4_col0" class="data row4 col0" >are you watching work schedules for boiler operators  guards  and other 24  hour day  7  day week operations in order to minimize overtime </td>
#       <td id="T_b0d55_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[25])
# Out:
# <style type="text/css">
# #T_5efe9_row0_col0, #T_5efe9_row0_col1, #T_5efe9_row1_col0, #T_5efe9_row1_col1, #T_5efe9_row2_col0, #T_5efe9_row2_col1, #T_5efe9_row3_col0, #T_5efe9_row3_col1, #T_5efe9_row4_col0, #T_5efe9_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_5efe9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5efe9_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_5efe9_row0_col0" class="data row0 col0" >are you careful to restrict the number of people on live at one time so that your total employment obligation is menimised</td>
#       <td id="T_5efe9_row0_col1" class="data row0 col1" >0.090909</td>
#     </tr>
#     <tr>
#       <th id="T_5efe9_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_5efe9_row1_col0" class="data row1 col0" >are you careful to restrict the number of people on leve at one time so that your total employment obligation is minimized</td>
#       <td id="T_5efe9_row1_col1" class="data row1 col1" >0.045455</td>
#     </tr>
#     <tr>
#       <th id="T_5efe9_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_5efe9_row2_col0" class="data row2 col0" >are you careful to restrict the number of people on leave at one time so that your total employment obligation is minimized</td>
#       <td id="T_5efe9_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5efe9_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_5efe9_row3_col0" class="data row3 col0" >are you careful to restrict the number of people on leave at one time so that your total employment obligation is minimized</td>
#       <td id="T_5efe9_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5efe9_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_5efe9_row4_col0" class="data row4 col0" >are you careful to restrict the number of people on leave at one time so that your total employment obligation is minimized </td>
#       <td id="T_5efe9_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[26])
# Out:
# <style type="text/css">
# #T_b4d94_row0_col0, #T_b4d94_row0_col1, #T_b4d94_row1_col0, #T_b4d94_row1_col1, #T_b4d94_row2_col0, #T_b4d94_row2_col1, #T_b4d94_row3_col0, #T_b4d94_row3_col1, #T_b4d94_row4_col0, #T_b4d94_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b4d94_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4d94_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_b4d94_row0_col0" class="data row0 col0" >have you considered use inventing equipment to replays or reduse the number of cafeteri emploies</td>
#       <td id="T_b4d94_row0_col1" class="data row0 col1" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_b4d94_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_b4d94_row1_col0" class="data row1 col0" >have you considered yous invending equipment to replace or reduce the number of caffetry employes</td>
#       <td id="T_b4d94_row1_col1" class="data row1 col1" >0.266667</td>
#     </tr>
#     <tr>
#       <th id="T_b4d94_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_b4d94_row2_col0" class="data row2 col0" >have you considered using vending equipment to replace or reduce the number of cafetery employees</td>
#       <td id="T_b4d94_row2_col1" class="data row2 col1" >0.066667</td>
#     </tr>
#     <tr>
#       <th id="T_b4d94_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_b4d94_row3_col0" class="data row3 col0" >have you considered using vending equipment to replace or reduce the number of cafetri employees</td>
#       <td id="T_b4d94_row3_col1" class="data row3 col1" >0.066667</td>
#     </tr>
#     <tr>
#       <th id="T_b4d94_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_b4d94_row4_col0" class="data row4 col0" >have you considered using vending equipment to replace or reduce the number of cafeteria employees </td>
#       <td id="T_b4d94_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[27])
# Out:
# <style type="text/css">
# #T_502c0_row0_col0, #T_502c0_row0_col1, #T_502c0_row1_col0, #T_502c0_row1_col1, #T_502c0_row2_col0, #T_502c0_row2_col1, #T_502c0_row3_col0, #T_502c0_row3_col1, #T_502c0_row4_col0, #T_502c0_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_502c0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_502c0_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_502c0_row0_col0" class="data row0 col0" >what are the possibilities for operating your caphateria for a single shift only and relying upon bending machines or prepacat sandwiches for the second and third shift operations</td>
#       <td id="T_502c0_row0_col1" class="data row0 col1" >0.107143</td>
#     </tr>
#     <tr>
#       <th id="T_502c0_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_502c0_row1_col0" class="data row1 col0" >what are the possibilities for operating your caphateria for a single shift only and relying upon bending machines or prepacked sandwiches for the second and third shift operations</td>
#       <td id="T_502c0_row1_col1" class="data row1 col1" >0.107143</td>
#     </tr>
#     <tr>
#       <th id="T_502c0_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_502c0_row2_col0" class="data row2 col0" >what are the possibilities for operating your ca feteria for a single shift only and relying upon vending machines or prepeckage sandwiches for the second and third shift operations</td>
#       <td id="T_502c0_row2_col1" class="data row2 col1" >0.107143</td>
#     </tr>
#     <tr>
#       <th id="T_502c0_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_502c0_row3_col0" class="data row3 col0" >what are the possibilities for operating your cafateria for a single sheift only and relying upon vending machines or prepackaged sandwiches for the second and third shift operations</td>
#       <td id="T_502c0_row3_col1" class="data row3 col1" >0.071429</td>
#     </tr>
#     <tr>
#       <th id="T_502c0_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_502c0_row4_col0" class="data row4 col0" >what are the possibilities for operating your cafeteria for a single shift only and relying upon vending machines or prepackaged sandwiches for the second  and third shift operations </td>
#       <td id="T_502c0_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[28])
# Out:
# <style type="text/css">
# #T_22afc_row0_col0, #T_22afc_row0_col1, #T_22afc_row1_col0, #T_22afc_row1_col1, #T_22afc_row2_col0, #T_22afc_row2_col1, #T_22afc_row3_col0, #T_22afc_row3_col1, #T_22afc_row4_col0, #T_22afc_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_22afc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22afc_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_22afc_row0_col0" class="data row0 col0" >av you checked the cost of sup contracting your confetri operation in order to save administrative costs</td>
#       <td id="T_22afc_row0_col1" class="data row0 col1" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_22afc_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_22afc_row1_col0" class="data row1 col0" >have you checked the cost of subcontracting yourcafetoryoperation in order to save administrative costs</td>
#       <td id="T_22afc_row1_col1" class="data row1 col1" >0.187500</td>
#     </tr>
#     <tr>
#       <th id="T_22afc_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_22afc_row2_col0" class="data row2 col0" >have you checked the cost of subcontracting your cafetery operation in order to save administrative costs</td>
#       <td id="T_22afc_row2_col1" class="data row2 col1" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_22afc_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_22afc_row3_col0" class="data row3 col0" >have you checked the cost of subcontracting your cafet ri operation in order to save administrative costs</td>
#       <td id="T_22afc_row3_col1" class="data row3 col1" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_22afc_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_22afc_row4_col0" class="data row4 col0" >have you checked the cost of subcontracting your cafeteria operation in order to save administrative costs </td>
#       <td id="T_22afc_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[29])
# Out:
# <style type="text/css">
# #T_9f319_row0_col0, #T_9f319_row0_col1, #T_9f319_row1_col0, #T_9f319_row1_col1, #T_9f319_row2_col0, #T_9f319_row2_col1, #T_9f319_row3_col0, #T_9f319_row3_col1, #T_9f319_row4_col0, #T_9f319_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_9f319_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f319_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_9f319_row0_col0" class="data row0 col0" >are there possibilities of having caffetriale poor par time on custodial or other jobs</td>
#       <td id="T_9f319_row0_col1" class="data row0 col1" >0.285714</td>
#     </tr>
#     <tr>
#       <th id="T_9f319_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_9f319_row1_col0" class="data row1 col0" >are there possibilities of having caphetrial port parteiman custodial or other jobs</td>
#       <td id="T_9f319_row1_col1" class="data row1 col1" >0.357143</td>
#     </tr>
#     <tr>
#       <th id="T_9f319_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_9f319_row2_col0" class="data row2 col0" >are there possibilities of having cafetria at por part-time an custodial or other jobs</td>
#       <td id="T_9f319_row2_col1" class="data row2 col1" >0.357143</td>
#     </tr>
#     <tr>
#       <th id="T_9f319_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_9f319_row3_col0" class="data row3 col0" >are there possibilities of having cafetrial pork part time on custodial or other jobs</td>
#       <td id="T_9f319_row3_col1" class="data row3 col1" >0.285714</td>
#     </tr>
#     <tr>
#       <th id="T_9f319_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_9f319_row4_col0" class="data row4 col0" >are there possibilities of having cafeteria help work parttime on custodial or other jobs </td>
#       <td id="T_9f319_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[30])
# Out:
# <style type="text/css">
# #T_55e52_row0_col0, #T_55e52_row0_col1, #T_55e52_row1_col0, #T_55e52_row1_col1, #T_55e52_row2_col0, #T_55e52_row2_col1, #T_55e52_row3_col0, #T_55e52_row3_col1, #T_55e52_row4_col0, #T_55e52_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_55e52_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55e52_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_55e52_row0_col0" class="data row0 col0" >can staggerd lunch periods relieve the capasti train on your feeding facilities</td>
#       <td id="T_55e52_row0_col1" class="data row0 col1" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_55e52_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_55e52_row1_col0" class="data row1 col0" >can staggard lunch periods relieve the capacity strain on your feeding facilities</td>
#       <td id="T_55e52_row1_col1" class="data row1 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_55e52_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_55e52_row2_col0" class="data row2 col0" >can staggerd lunch periods relieve the capacity strain on your feeding facilities</td>
#       <td id="T_55e52_row2_col1" class="data row2 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_55e52_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_55e52_row3_col0" class="data row3 col0" >can staggared lunch periods relieve the capacity strain on your feeding facilities</td>
#       <td id="T_55e52_row3_col1" class="data row3 col1" >0.083333</td>
#     </tr>
#     <tr>
#       <th id="T_55e52_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_55e52_row4_col0" class="data row4 col0" >can staggered lunch periods relieve the capacity strain on your feeding facilities </td>
#       <td id="T_55e52_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[31])
# Out:
# <style type="text/css">
# #T_518ec_row0_col0, #T_518ec_row0_col1, #T_518ec_row1_col0, #T_518ec_row1_col1, #T_518ec_row2_col0, #T_518ec_row2_col1, #T_518ec_row3_col0, #T_518ec_row3_col1, #T_518ec_row4_col0, #T_518ec_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_518ec_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_518ec_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_518ec_row0_col0" class="data row0 col0" >would it be feasible to lemin the manner in order to read yeur's fitting costs</td>
#       <td id="T_518ec_row0_col1" class="data row0 col1" >0.357143</td>
#     </tr>
#     <tr>
#       <th id="T_518ec_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_518ec_row1_col0" class="data row1 col0" >would it be feasiable to limit the manner in order to reduce feeding costs</td>
#       <td id="T_518ec_row1_col1" class="data row1 col1" >0.142857</td>
#     </tr>
#     <tr>
#       <th id="T_518ec_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_518ec_row2_col0" class="data row2 col0" >would it be feasible to limit the monu in order to reduce feeding costs</td>
#       <td id="T_518ec_row2_col1" class="data row2 col1" >0.071429</td>
#     </tr>
#     <tr>
#       <th id="T_518ec_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_518ec_row3_col0" class="data row3 col0" >would it be feasible to limit the manue in order to reduce feeding costs</td>
#       <td id="T_518ec_row3_col1" class="data row3 col1" >0.071429</td>
#     </tr>
#     <tr>
#       <th id="T_518ec_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_518ec_row4_col0" class="data row4 col0" >would it be feasible to limit the menu in order to reduce feeding costs </td>
#       <td id="T_518ec_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[32])
# Out:
# <style type="text/css">
# #T_bf242_row0_col0, #T_bf242_row0_col1, #T_bf242_row1_col0, #T_bf242_row1_col1, #T_bf242_row2_col0, #T_bf242_row2_col1, #T_bf242_row3_col0, #T_bf242_row3_col1, #T_bf242_row4_col0, #T_bf242_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_bf242_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf242_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_bf242_row0_col0" class="data row0 col0" >have you considered gradwel with drawal of subsidence to urinplan finingoberation</td>
#       <td id="T_bf242_row0_col1" class="data row0 col1" >0.692308</td>
#     </tr>
#     <tr>
#       <th id="T_bf242_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_bf242_row1_col0" class="data row1 col0" >have you considered gradual witdrawal of subsidies to your implaned fitting operation</td>
#       <td id="T_bf242_row1_col1" class="data row1 col1" >0.307692</td>
#     </tr>
#     <tr>
#       <th id="T_bf242_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_bf242_row2_col0" class="data row2 col0" >have you considered gradual withdrawal of subsidies to yourinplan feeding operation</td>
#       <td id="T_bf242_row2_col1" class="data row2 col1" >0.230769</td>
#     </tr>
#     <tr>
#       <th id="T_bf242_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_bf242_row3_col0" class="data row3 col0" >have you considered gradwell withdrawal of subsidies to your in plant feeding operation</td>
#       <td id="T_bf242_row3_col1" class="data row3 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_bf242_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_bf242_row4_col0" class="data row4 col0" >have you considered gradual withdrawal of subsidies to your in plant feeding operation </td>
#       <td id="T_bf242_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[33])
# Out:
# <style type="text/css">
# #T_8aeb1_row0_col0, #T_8aeb1_row0_col1, #T_8aeb1_row1_col0, #T_8aeb1_row1_col1, #T_8aeb1_row2_col0, #T_8aeb1_row2_col1, #T_8aeb1_row3_col0, #T_8aeb1_row3_col1, #T_8aeb1_row4_col0, #T_8aeb1_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_8aeb1_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8aeb1_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_8aeb1_row0_col0" class="data row0 col0" >are you utilizing cafaterias pace for company meetings or discussions</td>
#       <td id="T_8aeb1_row0_col1" class="data row0 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_8aeb1_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_8aeb1_row1_col0" class="data row1 col0" >are you utilizing capateria space for company meetings or discussions</td>
#       <td id="T_8aeb1_row1_col1" class="data row1 col1" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_8aeb1_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_8aeb1_row2_col0" class="data row2 col0" >are you utilizing cafeteria s pace for company meetings or discussions</td>
#       <td id="T_8aeb1_row2_col1" class="data row2 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_8aeb1_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_8aeb1_row3_col0" class="data row3 col0" >are you utilizing cafeteria space for company meetings or discussions</td>
#       <td id="T_8aeb1_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8aeb1_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_8aeb1_row4_col0" class="data row4 col0" >are you utilizing cafeteria space for company meetings or discussions </td>
#       <td id="T_8aeb1_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[34])
# Out:
# <style type="text/css">
# #T_10e69_row0_col0, #T_10e69_row0_col1, #T_10e69_row1_col0, #T_10e69_row1_col1, #T_10e69_row2_col0, #T_10e69_row2_col1, #T_10e69_row3_col0, #T_10e69_row3_col1, #T_10e69_row4_col0, #T_10e69_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_10e69_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10e69_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_10e69_row0_col0" class="data row0 col0" >are your expenses in this area commantorary with the number of emploies who benefit from your programme</td>
#       <td id="T_10e69_row0_col1" class="data row0 col1" >0.176471</td>
#     </tr>
#     <tr>
#       <th id="T_10e69_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_10e69_row1_col0" class="data row1 col0" >are your expenses in this area commenturate with the number of emploies who benefit from your programme</td>
#       <td id="T_10e69_row1_col1" class="data row1 col1" >0.176471</td>
#     </tr>
#     <tr>
#       <th id="T_10e69_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_10e69_row2_col0" class="data row2 col0" >are your expenses in this area commentiary with the number of employees who benefit from your program</td>
#       <td id="T_10e69_row2_col1" class="data row2 col1" >0.058824</td>
#     </tr>
#     <tr>
#       <th id="T_10e69_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_10e69_row3_col0" class="data row3 col0" >are your expenses in this area commercuary with the number of employees who benefit from your programme</td>
#       <td id="T_10e69_row3_col1" class="data row3 col1" >0.117647</td>
#     </tr>
#     <tr>
#       <th id="T_10e69_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_10e69_row4_col0" class="data row4 col0" >are your expenses in this area commensurate with the number of employees who benefit from your program </td>
#       <td id="T_10e69_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[35])
# Out:
# <style type="text/css">
# #T_6a0cc_row0_col0, #T_6a0cc_row0_col1, #T_6a0cc_row1_col0, #T_6a0cc_row1_col1, #T_6a0cc_row2_col0, #T_6a0cc_row2_col1, #T_6a0cc_row3_col0, #T_6a0cc_row3_col1, #T_6a0cc_row4_col0, #T_6a0cc_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_6a0cc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a0cc_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_6a0cc_row0_col0" class="data row0 col0" >have you aldited your program recently to wet out those phases that drove lis participation</td>
#       <td id="T_6a0cc_row0_col1" class="data row0 col1" >0.266667</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cc_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_6a0cc_row1_col0" class="data row1 col0" >have you aldited your programm recently to weed out those phases that draw lease participation</td>
#       <td id="T_6a0cc_row1_col1" class="data row1 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cc_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_6a0cc_row2_col0" class="data row2 col0" >have you audited your program recently to without those phases that drove leas participation</td>
#       <td id="T_6a0cc_row2_col1" class="data row2 col1" >0.266667</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cc_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_6a0cc_row3_col0" class="data row3 col0" >have you algited your program recently to wed out those phases that draw lees participation</td>
#       <td id="T_6a0cc_row3_col1" class="data row3 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cc_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_6a0cc_row4_col0" class="data row4 col0" >have you audited your program recently to weed out those phases that draw least participation </td>
#       <td id="T_6a0cc_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[36])
# Out:
# <style type="text/css">
# #T_e4f32_row0_col0, #T_e4f32_row0_col1, #T_e4f32_row1_col0, #T_e4f32_row1_col1, #T_e4f32_row2_col0, #T_e4f32_row2_col1, #T_e4f32_row3_col0, #T_e4f32_row3_col1, #T_e4f32_row4_col0, #T_e4f32_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e4f32_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4f32_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_e4f32_row0_col0" class="data row0 col0" >do employs contribute their share of money to recreational facilities</td>
#       <td id="T_e4f32_row0_col1" class="data row0 col1" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_e4f32_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_e4f32_row1_col0" class="data row1 col0" >do employs contribute their share of money to recretional facilities</td>
#       <td id="T_e4f32_row1_col1" class="data row1 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_e4f32_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_e4f32_row2_col0" class="data row2 col0" >do employees contribute their share of money to recreational facilities</td>
#       <td id="T_e4f32_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e4f32_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_e4f32_row3_col0" class="data row3 col0" >do employees contribute their share of money to recreational facilities</td>
#       <td id="T_e4f32_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e4f32_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_e4f32_row4_col0" class="data row4 col0" >do employees contribute their share of money to recreational facilities </td>
#       <td id="T_e4f32_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[37])
# Out:
# <style type="text/css">
# #T_eda86_row0_col0, #T_eda86_row0_col1, #T_eda86_row1_col0, #T_eda86_row1_col1, #T_eda86_row2_col0, #T_eda86_row2_col1, #T_eda86_row3_col0, #T_eda86_row3_col1, #T_eda86_row4_col0, #T_eda86_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_eda86_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eda86_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_eda86_row0_col0" class="data row0 col0" >have you considered delegating operation or responsibility to your employ association and carefully restricting your plans financial contribution</td>
#       <td id="T_eda86_row0_col1" class="data row0 col1" >0.277778</td>
#     </tr>
#     <tr>
#       <th id="T_eda86_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_eda86_row1_col0" class="data row1 col0" >have you considered delegating operation a responsibility to your employed association and carefully restricting your plans financial contribution</td>
#       <td id="T_eda86_row1_col1" class="data row1 col1" >0.277778</td>
#     </tr>
#     <tr>
#       <th id="T_eda86_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_eda86_row2_col0" class="data row2 col0" >have you considered delegating operational responsibility to your employe association and carefully restricting your plan's financial contribution</td>
#       <td id="T_eda86_row2_col1" class="data row2 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_eda86_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_eda86_row3_col0" class="data row3 col0" >have you considered delegating operational responsibility to your employ association and carefully restricting your plan's financial contribution</td>
#       <td id="T_eda86_row3_col1" class="data row3 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_eda86_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_eda86_row4_col0" class="data row4 col0" >have you considered delegating operational responsibility to your employee association and carefully restricting your plant s financial contribution </td>
#       <td id="T_eda86_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[38])
# Out:
# <style type="text/css">
# #T_48575_row0_col0, #T_48575_row0_col1, #T_48575_row1_col0, #T_48575_row1_col1, #T_48575_row2_col0, #T_48575_row2_col1, #T_48575_row3_col0, #T_48575_row3_col1, #T_48575_row4_col0, #T_48575_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_48575_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48575_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_48575_row0_col0" class="data row0 col0" >could and employse gardenclot take over partial care of plant grounds</td>
#       <td id="T_48575_row0_col1" class="data row0 col1" >0.384615</td>
#     </tr>
#     <tr>
#       <th id="T_48575_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_48575_row1_col0" class="data row1 col0" >could and employs garden club take over partial care of plant grounds</td>
#       <td id="T_48575_row1_col1" class="data row1 col1" >0.230769</td>
#     </tr>
#     <tr>
#       <th id="T_48575_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_48575_row2_col0" class="data row2 col0" >coudan employees garden club take over partial care of plant grounds</td>
#       <td id="T_48575_row2_col1" class="data row2 col1" >0.307692</td>
#     </tr>
#     <tr>
#       <th id="T_48575_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_48575_row3_col0" class="data row3 col0" >could and employees gard and club take over partial care of plant grounds</td>
#       <td id="T_48575_row3_col1" class="data row3 col1" >0.307692</td>
#     </tr>
#     <tr>
#       <th id="T_48575_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_48575_row4_col0" class="data row4 col0" >could an employee s garden club take over partial care of plant grounds </td>
#       <td id="T_48575_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
show_semcor_transcriptions_comparison(outs[39])
# Out:
# <style type="text/css">
# #T_fd446_row0_col0, #T_fd446_row0_col1, #T_fd446_row1_col0, #T_fd446_row1_col1, #T_fd446_row2_col0, #T_fd446_row2_col1, #T_fd446_row3_col0, #T_fd446_row3_col1, #T_fd446_row4_col0, #T_fd446_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_fd446_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Transcription</th>
#       <th class="col_heading level0 col1" >WER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd446_level0_row0" class="row_heading level0 row0" >BASE_MODEL</th>
#       <td id="T_fd446_row0_col0" class="data row0 col0" >vuda canra club be useful in taking pictures pertenin to a plan safety</td>
#       <td id="T_fd446_row0_col1" class="data row0 col1" >0.461538</td>
#     </tr>
#     <tr>
#       <th id="T_fd446_level0_row1" class="row_heading level0 row1" >LARGE_MODEL</th>
#       <td id="T_fd446_row1_col0" class="data row1 col0" >vouda camera clab be useful in taking pictures pertenan to plan safety</td>
#       <td id="T_fd446_row1_col1" class="data row1 col1" >0.384615</td>
#     </tr>
#     <tr>
#       <th id="T_fd446_level0_row2" class="row_heading level0 row2" >XLSR_MODEL</th>
#       <td id="T_fd446_row2_col0" class="data row2 col0" >would the camera club be useful in taking pictures perteinant to plant safety</td>
#       <td id="T_fd446_row2_col1" class="data row2 col1" >0.153846</td>
#     </tr>
#     <tr>
#       <th id="T_fd446_level0_row3" class="row_heading level0 row3" >HUBERT_MODEL</th>
#       <td id="T_fd446_row3_col0" class="data row3 col0" >vouda camera club be useful in taking pictures pertinant to plan safety</td>
#       <td id="T_fd446_row3_col1" class="data row3 col1" >0.307692</td>
#     </tr>
#     <tr>
#       <th id="T_fd446_level0_row4" class="row_heading level0 row4" >SemCor</th>
#       <td id="T_fd446_row4_col0" class="data row4 col0" >would a camera club be useful in taking pictures pertinent to plant safety </td>
#       <td id="T_fd446_row4_col1" class="data row4 col1" ></td>
#     </tr>
#   </tbody>
# </table>
